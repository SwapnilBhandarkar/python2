# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
var=pd.read_csv('auto-mpg.csv')
df=pd.DataFrame(var)
print(df)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.describe(include="all")
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
df.describe(exclude="all")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-99c1dcffb01f> in <module>
# ----> 1 df.describe(exclude="all")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10094             data = self
#   10095         else:
# > 10096             data = self.select_dtypes(include=include, exclude=exclude)
#   10097
#   10098         ldesc = [describe_1d(s) for _, s in data.items()]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3566         # convert the myriad valid dtypes object to a single representation
#    3567         include = frozenset(infer_dtype_from_object(x) for x in include)
# -> 3568         exclude = frozenset(infer_dtype_from_object(x) for x in exclude)
# ...

# %%
df.describe(exclude="int64")
# Out:
#                mpg  displacement horsepower  acceleration    car name
# count   398.000000    398.000000        398    398.000000         398
# unique         NaN           NaN         94           NaN         305
# top            NaN           NaN        150           NaN  ford pinto
# freq           NaN           NaN         22           NaN           6
# mean     23.514573    193.425879        NaN     15.568090         NaN
# std       7.815984    104.269838        NaN      2.757689         NaN
# min       9.000000     68.000000        NaN      8.000000         NaN
# 25%      17.500000    104.250000        NaN     13.825000         NaN
# 50%      23.000000    148.500000        NaN     15.500000         NaN
# 75%      29.000000    262.000000        NaN     17.175000         NaN
# max      46.600000    455.000000        NaN     24.800000         NaN

# %%
df.describe(include="float64")
# Out:
#               mpg  displacement  acceleration
# count  398.000000    398.000000    398.000000
# mean    23.514573    193.425879     15.568090
# std      7.815984    104.269838      2.757689
# min      9.000000     68.000000      8.000000
# 25%     17.500000    104.250000     13.825000
# 50%     23.000000    148.500000     15.500000
# 75%     29.000000    262.000000     17.175000
# max     46.600000    455.000000     24.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
print(df.to_string())
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model year  origin                              car name
# 0    18.0          8         307.0        130    3504          12.0          70       1             chevrolet chevelle malibu
# 1    15.0          8         350.0        165    3693          11.5          70       1                     buick skylark 320
# 2    18.0          8         318.0        150    3436          11.0          70       1                    plymouth satellite
# 3    16.0          8         304.0        150    3433          12.0          70       1                         amc rebel sst
# 4    17.0          8         302.0        140    3449          10.5          70       1                           ford torino
# 5    15.0          8         429.0        198    4341          10.0          70       1                      ford galaxie 500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=[15,15],marker='*',diagonal="kde")
plt.show()

# %%
df.plot()
plt.figure(figsize=(15,15))
plt.show()

# %%
df=pd.read_csv("bollywood.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   movie   1501 non-null   object
#  1   lead    1501 non-null   object
# dtypes: object(2)
# memory usage: 23.6+ KB

# %%
print(df.to_string())
# Out:
#                                                movie                     lead
# 0                           Uri: The Surgical Strike            Vicky Kaushal
# 1                                      Battalion 609              Vicky Ahuja
# 2               The Accidental Prime Minister (film)              Anupam Kher
# 3                                    Why Cheat India            Emraan Hashmi
# 4                                    Evening Shadows         Mona Ambegaonkar
# 5                                        Soni (film)     Geetika Vidya Ohlyan
# 6                                      Fraud Saiyaan             Arshad Warsi
# 7                                         Bombairiya             Radhika Apte
# 8                   Manikarnika: The Queen of Jhansi           Kangana Ranaut
# 9                                   Thackeray (film)      Nawazuddin Siddiqui
# 10                                            Amavas                Ali Asgar
# ...

# %%
df['lead']
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1495      Shah Rukh Khan
# 1496    Amitabh Bachchan
# 1497        Vivek Oberoi
# 1498          Ajay Devgn
# 1499        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # 1) print lead column
# # 2) print movie in which vicky kaushal has worked
# # 3) print only movie name in which VK has worked
# # 4) convert dataframe of two columns into series with moviename as index
# # 5) name of actor worked in film(mantra (2016))

# %%
df[df["lead"]=='Vicky Kaushal']
# Out:
#                        movie           lead
# 0   Uri: The Surgical Strike  Vicky Kaushal
# 86      Love per Square Foot  Vicky Kaushal

# %%
df['movie'].loc[df['lead']=='Vicky Kaushal']
# Out:
# 0     Uri: The Surgical Strike
# 86        Love per Square Foot
# Name: movie, dtype: object

# %%
data=pd.read_csv("bollywood.csv",index_col="movie",squeeze=True)
print(data)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
print(df[df['lead']=='Anupam Kher'])
# Out:
#                                      movie         lead
# 2     The Accidental Prime Minister (film)  Anupam Kher
# 38              One Day: Justice Delivered  Anupam Kher
# 386                  Dirty Politics (film)  Anupam Kher
# 524                        Singham Returns  Anupam Kher
# 550               Ekkees Toppon Ki Salaami  Anupam Kher
# 611                   Hum Hai Raahi Car Ke  Anupam Kher
# 692                   Mr. Bhatti on Chutti  Anupam Kher
# 792               Sahi Dhandhe Galat Bande  Anupam Kher
# 950                         Yeh Mera India  Anupam Kher
# 1041                      Meerabai Not Out  Anupam Kher
# 1182                      Khosla Ka Ghosla  Anupam Kher
# 1277            Maine Gandhi Ko Nahin Mara  Anupam Kher
# 1401      Shukriya: Till Death Do Us Apart  Anupam Kher

# %%
print(df[df['lead']=='Anupam Kher'])
# Out:
#                                      movie         lead
# 2     The Accidental Prime Minister (film)  Anupam Kher
# 38              One Day: Justice Delivered  Anupam Kher
# 250                     Kuch Kuch Hota Hai  Anupam Kher
# 387                  Dirty Politics (film)  Anupam Kher
# 525                        Singham Returns  Anupam Kher
# 551               Ekkees Toppon Ki Salaami  Anupam Kher
# 612                   Hum Hai Raahi Car Ke  Anupam Kher
# 693                   Mr. Bhatti on Chutti  Anupam Kher
# 793               Sahi Dhandhe Galat Bande  Anupam Kher
# 951                         Yeh Mera India  Anupam Kher
# 1042                      Meerabai Not Out  Anupam Kher
# 1183                      Khosla Ka Ghosla  Anupam Kher
# 1278            Maine Gandhi Ko Nahin Mara  Anupam Kher
# 1402      Shukriya: Till Death Do Us Apart  Anupam Kher

# %%
print(df['lead'][df['movie']=='Mantra (2016 film)'])
# Out:
# 177    Rajat Kapoor
# Name: lead, dtype: object

# %%
import numpy as np
d1.size
# Out:
# 29322

# %%
d1=pd.read_csv("movies.csv")
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
d1.describe(include="all")
# Out:
#        title_x    imdb_id                                        poster_path  \
# count     1629       1629                                               1526
# unique    1625       1623                                               1517
# top     Andaaz  tt2424988  https://upload.wikimedia.org/wikipedia/en/thum...
# freq         2          2                                                  4
# mean       NaN        NaN                                                NaN
# std        NaN        NaN                                                NaN
# min        NaN        NaN                                                NaN
# 25%        NaN        NaN                                                NaN
# 50%        NaN        NaN                                                NaN
# 75%        NaN        NaN                                                NaN
# max        NaN        NaN                                                NaN
#
# ...

# %%
print(d1.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # 1) print number of movies with imdb rating > 8

# %%
d1[d1['imdb_rating']>8].shape[0]
# Out:
# 60

# %% [markdown]
# # 2) title and imdb rating of movie of type drama

# %%
d1[['title_x','imdb_rating']].loc[d1['genres']=="Drama"]
# Out:
#                         title_x  imdb_rating
# 4               Evening Shadows          7.3
# 5                   Soni (film)          7.2
# 12                    Hum Chaar          5.6
# 17                 Hamid (film)          7.7
# 20    Mere Pyare Prime Minister          6.8
# ...                         ...          ...
# 1595                     Dattak          7.5
# 1601           Maya (2001 film)          7.0
# 1618               Rahul (film)          5.5
# 1624      Tera Mera Saath Rahen          4.9
# 1625       Yeh Zindagi Ka Safar          3.0
#
# [162 rows x 2 columns]

# %%
d1[['title_x','imdb_rating']].loc[(d1['imdb_rating']>8) & (d1['imdb_rating']<9 )]
# Out:
#                                 title_x  imdb_rating
# 0              Uri: The Surgical Strike          8.4
# 11                            Gully Boy          8.2
# 37                    Article 15 (film)          8.3
# 40                      Super 30 (film)          8.2
# 53                          Section 375          8.4
# 58                    Ghost (2019 film)          8.7
# 59                     Bala (2019 film)          8.2
# 62                       Saand Ki Aankh          8.9
# 64                          Ujda Chaman          8.1
# 84                            Mukkabaaz          8.1
# 143                             Tumbbad          8.2
# 146                           Andhadhun          8.4
# 192            Sachin: A Billion Dreams          8.6
# 207                          G Kutta Se          8.3
# 216      Yadvi – The Dignified Princess          8.2
# 219                    Raag Desh (film)          8.3
# 279                  Nil Battey Sannata          8.4
# ...
